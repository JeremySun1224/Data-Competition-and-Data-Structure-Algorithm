# %%
from __future__ import print_function, division
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)  # 显示所有行
pd.set_option('display.max_columns', None)  # 显示所有列
# pd.set_option('display.width', 1000)

# %% [markdown]
# # merge用法

# %% [markdown]
# ## merge删除重复列

# %%
left = pd.DataFrame({
    'key':['K0', 'K1', 'K2', 'K3'],
    'A':['A0', 'A1', 'A2', 'A3'],
    'B':['B0', 'B1', 'B2', 'B3']
})
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right = pd.DataFrame({
    'key':['K0', 'K1', 'K2', 'K3'],
    'C':['C0', 'C1', 'C2', 'C3'],
    'D':['D0', 'D1', 'D2', 'D3'] 
})
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
result = pd.merge(left=right, right=left, on='key')

# %%
result
# Out:
#   key   C   D   A   B
# 0  K0  C0  D0  A0  B0
# 1  K1  C1  D1  A1  B1
# 2  K2  C2  D2  A2  B2
# 3  K3  C3  D3  A3  B3

# %%
left = pd.DataFrame({
    'key1':['K0', 'K1', 'K2', 'K3'],
    'A':['A0', 'A1', 'A2', 'A3'],
    'B':['B0', 'B1', 'B2', 'B3']
})
left
# Out:
#   key1   A   B
# 0   K0  A0  B0
# 1   K1  A1  B1
# 2   K2  A2  B2
# 3   K3  A3  B3

# %%
right = pd.DataFrame({
    'key2':['K0', 'K1', 'K2', 'K3'],
    'C':['C0', 'C1', 'C2', 'C3'],
    'D':['D0', 'D1', 'D2', 'D3'] 
})
right
# Out:
#   key2   C   D
# 0   K0  C0  D0
# 1   K1  C1  D1
# 2   K2  C2  D2
# 3   K3  C3  D3

# %%
result = pd.merge(left=left, right=right, left_on='key1', right_on='key2')

# %%
result
# Out:
#   key1   A   B key2   C   D
# 0   K0  A0  B0   K0  C0  D0
# 1   K1  A1  B1   K1  C1  D1
# 2   K2  A2  B2   K2  C2  D2
# 3   K3  A3  B3   K3  C3  D3

# %%
result = pd.merge(left=left, right=right, left_on='key1', right_on='key2').drop('key1', axis=1)

# %%
result
# Out:
#     A   B key2   C   D
# 0  A0  B0   K0  C0  D0
# 1  A1  B1   K1  C1  D1
# 2  A2  B2   K2  C2  D2
# 3  A3  B3   K3  C3  D3

# %% [markdown]
# ## 参数how的用法

# %% [markdown]
# ### inner内连接取交集

# %%
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})


result = pd.merge(left, right, left_on='key1', right_on='key2', how='inner')
result
# Out:
#   key1   A   B key2   C   D
# 0   K0  A0  B0   K0  C0  D0
# 1   K1  A1  B1   K1  C1  D1
# 2   K2  A2  B2   K2  C2  D2
# 3   K3  A3  B3   K3  C3  D3

# %% [markdown]
# ### outer外连接取并集，空值用NaN替换

# %%
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})


result = pd.merge(left, right, left_on='key1', right_on='key2', how='outer')
result
# Out:
#   key1    A    B key2    C    D
# 0   K0   A0   B0   K0   C0   D0
# 1   K1   A1   B1   K1   C1   D1
# 2   K2   A2   B2   K2   C2   D2
# 3   K3   A3   B3   K3   C3   D3
# 4   K4   A4   B4  NaN  NaN  NaN
# 5  NaN  NaN  NaN   K5   C4   D4

# %% [markdown]
# ### left 左外连接，左侧取全部，右侧取部分

# %%
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})### left 左连接，左侧取全部，右侧取部分


result = pd.merge(left, right, left_on='key1', right_on='key2', how='left')
result
# Out:
#   key1   A   B key2    C    D
# 0   K0  A0  B0   K0   C0   D0
# 1   K1  A1  B1   K1   C1   D1
# 2   K2  A2  B2   K2   C2   D2
# 3   K3  A3  B3   K3   C3   D3
# 4   K4  A4  B4  NaN  NaN  NaN

# %% [markdown]
# ### right 右外连接，右侧取全部，左侧取部分

# %%
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3','K4'],
                      'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})


right = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3','K5'],
                     'C': ['C0', 'C1', 'C2', 'C3','C4'],
                     'D': ['D0', 'D1', 'D2', 'D3','D4']})


result = pd.merge(left, right, left_on='key1', right_on='key2', how='right')
result
# Out:
#   key1    A    B key2   C   D
# 0   K0   A0   B0   K0  C0  D0
# 1   K1   A1   B1   K1  C1  D1
# 2   K2   A2   B2   K2  C2  D2
# 3   K3   A3   B3   K3  C3  D3
# 4  NaN  NaN  NaN   K5  C4  D4

# %% [markdown]
# # groupby用法

# %%
# groupby()主要的作用是进行数据的分组以及分组后地组内运算。

# %%
# groupby示意图

# %% [markdown]
# <img src='./groupby.png' height=400 width=600>

# %%
# 读取数据

# %%
df = pd.read_csv('./data/train_set.csv', nrows=1000)  # 读取前1000行数据

# %%
df.head()
# Out:
#    ID  age         job   marital  education default  balance housing loan   contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   1   43  management   married   tertiary      no      291     yes   no   unknown    9   may       150         2     -1         0  unknown  0
# 1   2   42  technician  divorced    primary      no     5076     yes   no  cellular    7   apr        99         1    251         2    other  0
# 2   3   47      admin.   married  secondary      no      104     yes  yes  cellular   14   jul        77         2     -1         0  unknown  0
# 3   4   28  management    single  secondary      no     -994     yes  yes  cellular   18   jul       174         2     -1         0  unknown  0
# 4   5   42  technician  divorced  secondary      no     2974     yes   no   unknown   21   may       187         5     -1         0  unknown  0

# %%
print(set(df['job']))
# Out:
# {'management', 'technician', 'unknown', 'admin.', 'housemaid', 'blue-collar', 'entrepreneur', 'unemployed', 'services', 'retired', 'student', 'self-employed'}

# %%
len(set(df['job']))
# Out:
# 12

# %%
# groupby对象

# %%
groupby_age = df.groupby('age')
print(type(groupby_age))
print(groupby_age)
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000024A69F86240>

# %%
groupby_age_marital = df.groupby(['age', 'marital'])
print(groupby_age_marital.size())
print(groupby_age_marital)
# Out:
# age  marital
# 20   single      1
# 21   married     1
#      single      1
# 22   single      1
# 23   married     1
#                 ..
# 79   divorced    1
# 80   divorced    1
# 81   divorced    1
# 83   divorced    1
#      married     1
# Length: 123, dtype: int64
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000024A69F86278>

# %%
df.groupby('job')['age'].mean()
# Out:
# job
# admin.           39.580645
# blue-collar      40.268722
# entrepreneur     41.296296
# housemaid        45.842105
# management       40.480392
# retired          61.163265
# self-employed    42.088235
# services         40.712963
# student          27.363636
# technician       40.406897
# unemployed       41.156250
# unknown          50.000000
# Name: age, dtype: float64

# %%
df.groupby('job')['age'].count()
# Out:
# job
# admin.           124
# blue-collar      227
# entrepreneur      27
# housemaid         19
# management       204
# retired           49
# self-employed     34
# services         108
# student           22
# technician       145
# unemployed        32
# unknown            9
# Name: age, dtype: int64

# %% [markdown]
# ## transform用法

# %% [markdown]
# ### transform()+自定义方法

# %%
data = pd.read_csv(filepath_or_buffer='./data/test_set.csv')

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown

# %%
data['job_age_count'] = data.groupby(['job'])['age'].transform(lambda x: x.count())
data['job_age_sum'] = data.groupby(['job'])['age'].transform(lambda x: x.sum())
data['job_age_max'] = data.groupby(['job'])['age'].transform(lambda x: x.max())
data['job_age_min'] = data.groupby(['job'])['age'].transform(lambda x: x.min())
data['job_age_mean'] = data.groupby(['job'])['age'].transform(lambda x: x.mean())
data['job_age_std'] = data.groupby(['job'])['age'].transform(lambda x: x.std())

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count  job_age_sum  job_age_max  job_age_min  job_age_mean  \
# 0            316        14818           83           23     46.892405
# 1           2299        93373           81           21     40.614615
# 2            555        34032           94           33     61.318919
# 3            249         6562           41           18     26.353414
# 4            316        14818           83           23     46.892405
#
#    job_age_std
# 0    10.496612
# 1     9.363107
# 2     9.010679
# 3     4.540543
# 4    10.496612

# %% [markdown]
# ### transform()+内置方法

# %%
data = pd.read_csv(filepath_or_buffer='./data/test_set.csv')

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown

# %%
data['job_age_count'] = data.groupby(['job'])['age'].transform('count')
data['job_age_sum'] = data.groupby(['job'])['age'].transform(sum)
data['job_age_max'] = data.groupby(['job'])['age'].transform(max)
data['job_age_min'] = data.groupby(['job'])['age'].transform(min)
data['job_age_mean'] = data.groupby(['job'])['age'].transform('mean')
data['job_age_std'] = data.groupby(['job'])['age'].transform('std')

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count  job_age_sum  job_age_max  job_age_min  job_age_mean  \
# 0            316        14818           83           23     46.892405
# 1           2299        93373           81           21     40.614615
# 2            555        34032           94           33     61.318919
# 3            249         6562           41           18     26.353414
# 4            316        14818           83           23     46.892405
#
#    job_age_std
# 0    10.496612
# 1     9.363107
# 2     9.010679
# 3     4.540543
# 4    10.496612

# %% [markdown]
# ## apply用法

# %%
data = pd.read_csv(filepath_or_buffer='./data/test_set.csv')

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown

# %%
data.groupby(['job'])['age'].apply(lambda x: x.count())
data.groupby(['job'])['age'].apply(lambda x: x.sum())
data.groupby(['job'])['age'].apply(lambda x: x.max())
data.groupby(['job'])['age'].apply(lambda x: x.min())
data.groupby(['job'])['age'].apply(lambda x: x.mean())
data.groupby(['job'])['age'].apply(lambda x: x.std())
# Out:
# job
# admin.            9.505032
# blue-collar       9.103816
# entrepreneur      9.191830
# housemaid        10.496612
# management        9.363107
# retired           9.010679
# self-employed     9.639098
# services          9.167455
# student           4.540543
# technician        9.054972
# unemployed        9.872712
# unknown          10.791540
# Name: age, dtype: float64

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown
#
#    job_age_count  job_age_sum  job_age_max  job_age_min  job_age_mean  \
# 0            NaN          NaN          NaN          NaN           NaN
# 1            NaN          NaN          NaN          NaN           NaN
# 2            NaN          NaN          NaN          NaN           NaN
# 3            NaN          NaN          NaN          NaN           NaN
# 4            NaN          NaN          NaN          NaN           NaN
#
#    job_age_std
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## agg用法

# %% [markdown]
# ### agg()+自定义方法

# %%
data = pd.read_csv(filepath_or_buffer='./data/test_set.csv')

# %%
data.groupby(['job'])['age'].agg(lambda x: x.count())
data.groupby(['job'])['age'].agg(lambda x: x.sum)
data.groupby(['job'])['age'].agg(lambda x: x.max)
data.groupby(['job'])['age'].agg(lambda x: x.min)
data.groupby(['job'])['age'].agg(lambda x: x.mean())
data.groupby(['job'])['age'].agg(lambda x: x.std())
# Out:
# job
# admin.            9.505032
# blue-collar       9.103816
# entrepreneur      9.191830
# housemaid        10.496612
# management        9.363107
# retired           9.010679
# self-employed     9.639098
# services          9.167455
# student           4.540543
# technician        9.054972
# unemployed        9.872712
# unknown          10.791540
# Name: age, dtype: float64

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0  telephone   29   jul       308         3     -1         0  unknown
# 1   cellular   20   nov       110         2     -1         0  unknown
# 2  telephone   30   jul       130         3     -1         0  unknown
# 3   cellular   30   jun       598         4    105         5  failure
# 4   cellular   15   jul       368         4     -1         0  unknown

# %%
data.groupby(['job'])['age'].agg('count')
data.groupby(['job'])['age'].agg(sum)
data.groupby(['job'])['age'].agg(max)
data.groupby(['job'])['age'].agg(min)
data.groupby(['job'])['age'].agg('mean')
# Out:
# job
# admin.           39.622222
# blue-collar      40.163849
# entrepreneur     42.395137
# housemaid        46.892405
# management       40.614615
# retired          61.318919
# self-employed    40.398977
# services         38.942029
# student          26.353414
# technician       39.380565
# unemployed       40.399381
# unknown          47.316667
# Name: age, dtype: float64

# %%
agg_count = data.groupby(['job'])['age'].agg({
    'job_age_count2': 'count',
    'job_age_sum2': 'sum',
    'job_age_max2': 'max',
    'job_age_min2': 'min',
    'job_age_mean2': 'mean'
})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version

# %%
agg_count
# Out:
#                job_age_count2  job_age_sum2  job_age_max2  job_age_min2  \
# job
# admin.                   1215         48141            69            20
# blue-collar              2307         92658            75            21
# entrepreneur              329         13948            84            26
# housemaid                 316         14818            83            23
# management               2299         93373            81            21
# retired                   555         34032            94            33
# self-employed             391         15796            76            22
# services                  966         37618            60            20
# student                   249          6562            41            18
# technician               1842         72539            70            21
# unemployed                323         13049            60            21
# unknown                    60          2839            75            25
#
#                job_age_mean2
# job
# admin.             39.622222
# blue-collar        40.163849
# entrepreneur       42.395137
# housemaid          46.892405
# management         40.614615
# retired            61.318919
# self-employed      40.398977
# services           38.942029
# student            26.353414
# technician         39.380565
# unemployed         40.399381
# unknown            47.316667

# %%
data = pd.merge(data, agg_count, on='job', how='left')

# %%
data
# Out:
#           ID  age          job   marital  education default  balance housing  \
# 0      25318   51    housemaid   married    unknown      no      174      no
# 1      25319   32   management   married   tertiary      no     6059     yes
# 2      25320   60      retired   married    primary      no        0      no
# 3      25321   32      student    single   tertiary      no       64      no
# 4      25322   41    housemaid   married  secondary      no        0     yes
# 5      25323   26   technician   married  secondary      no     -293     yes
# 6      25324   37     services   married  secondary      no      405     yes
# 7      25325   31      student    single   tertiary      no      117     yes
# 8      25326   45   management   married  secondary      no      424     yes
# 9      25327   33       admin.    single  secondary      no     1437     yes
# 10     25328   53   management   married   tertiary      no     2578      no
# 11     25329   35   technician    single  secondary      no     5731     yes
# 12     25330   55  blue-collar  divorced  secondary      no     -152     yes
# 13     25331   37  blue-collar    single  secondary      no      134     yes
# 14     25332   34     services    single  secondary      no     8132     yes
# 15     25333   37   technician    single  secondary      no      466     yes
# 16     25334   55   management   married   tertiary      no     3848     yes
# 17     25335   41     services   married  secondary      no     1483     yes
# 18     25336   46  blue-collar   married  secondary      no      345     yes
# 19     25337   33   management    single  secondary      no        0     yes
# 20     25338   29  blue-collar   married    primary      no      201     yes
# 21     25339   34   technician   married   tertiary      no        0      no
# 22     25340   39   technician   married    unknown      no      880     yes
# 23     25341   32   management    single   tertiary      no      631      no
# 24     25342   38  blue-collar    single    primary      no        0     yes
# 25     25343   37     services   married  secondary      no      217     yes
# 26     25344   25     services    single  secondary      no       88     yes
# 27     25345   45  blue-collar   married    unknown      no      818     yes
# 28     25346   50     services   married    unknown      no     1688      no
# 29     25347   33  blue-collar   married    primary      no      -81     yes
# ...      ...  ...          ...       ...        ...     ...      ...     ...
# 10822  36140   35       admin.    single   tertiary      no     2622      no
# 10823  36141   36   technician   married   tertiary      no       71      no
# 10824  36142   35   technician    single  secondary      no      127      no
# 10825  36143   39   technician   married  secondary      no     1385     yes
# 10826  36144   33  blue-collar  divorced  secondary      no      744     yes
# 10827  36145   40       admin.   married   tertiary      no     1108      no
# 10828  36146   57      retired   married  secondary      no     1841      no
# 10829  36147   38   technician   married   tertiary      no     4383      no
# 10830  36148   40   management   married   tertiary      no      526     yes
# 10831  36149   39  blue-collar    single  secondary      no    16917      no
# 10832  36150   35   management   married   tertiary      no     5367      no
# 10833  36151   26   unemployed    single  secondary      no      461      no
# 10834  36152   32   management   married   tertiary      no     4945      no
# 10835  36153   39  blue-collar   married    primary      no      800     yes
# 10836  36154   38   management   married   tertiary      no      413      no
# 10837  36155   58   technician  divorced  secondary      no     -123      no
# 10838  36156   54  blue-collar   married  secondary      no      548      no
# 10839  36157   53   technician   married    unknown      no     6921     yes
# 10840  36158   36     services  divorced  secondary      no     2390     yes
# 10841  36159   34     services    single  secondary      no       49      no
# 10842  36160   37       admin.  divorced  secondary      no        0     yes
# 10843  36161   51   technician   married  secondary      no     1123      no
# 10844  36162   38       admin.   married  secondary      no       70      no
# 10845  36163   57  blue-collar   married    primary      no      137      no
# 10846  36164   28   management    single   tertiary      no       78      no
# 10847  36165   29   management    single   tertiary      no       54     yes
# 10848  36166   35   management   married  secondary      no      674      no
# 10849  36167   38     services   married  secondary      no      435     yes
# 10850  36168   41       admin.  divorced  secondary      no      783     yes
# 10851  36169   34  blue-collar   married    primary      no    15841     yes
#
#       loan    contact  ...  duration campaign  pdays  previous  poutcome  \
# 0       no  telephone  ...       308        3     -1         0   unknown
# 1       no   cellular  ...       110        2     -1         0   unknown
# 2       no  telephone  ...       130        3     -1         0   unknown
# 3       no   cellular  ...       598        4    105         5   failure
# 4      yes   cellular  ...       368        4     -1         0   unknown
# 5      yes    unknown  ...        64        2     -1         0   unknown
# 6       no    unknown  ...        51        2     -1         0   unknown
# 7       no  telephone  ...        41        1     -1         0   unknown
# 8      yes   cellular  ...       216        5     -1         0   unknown
# 9       no    unknown  ...       641        1     -1         0   unknown
# 10      no   cellular  ...       958        2     -1         0   unknown
# 11      no   cellular  ...       164        2    167         4     other
# 12      no   cellular  ...        36        3     -1         0   unknown
# 13      no    unknown  ...       200        1     -1         0   unknown
# 14      no    unknown  ...       137        1     -1         0   unknown
# 15      no    unknown  ...       231        2     -1         0   unknown
# 16      no   cellular  ...       222        2     -1         0   unknown
# 17      no    unknown  ...        66        4     -1         0   unknown
# 18     yes  telephone  ...        86        1    259         3     other
# 19      no    unknown  ...       816        2     -1         0   unknown
# 20      no   cellular  ...       101       12     -1         0   unknown
# 21      no   cellular  ...        89        1    133         1   failure
# 22      no    unknown  ...        29        1     -1         0   unknown
# 23      no   cellular  ...       145        5     -1         0   unknown
# 24      no   cellular  ...       775        1     -1         0   unknown
# 25      no   cellular  ...       152        1     -1         0   unknown
# 26      no   cellular  ...       121       18     -1         0   unknown
# 27      no    unknown  ...       343        3     -1         0   unknown
# 28      no  telephone  ...       156        2     -1         0   unknown
# 29      no    unknown  ...       267        1     -1         0   unknown
# ...    ...        ...  ...       ...      ...    ...       ...       ...
# 10822   no   cellular  ...       374        5     -1         0   unknown
# 10823   no   cellular  ...       587        2     -1         0   unknown
# 10824   no   cellular  ...       203        1     -1         0   unknown
# 10825  yes  telephone  ...       446        1     -1         0   unknown
# 10826   no   cellular  ...        59        3     -1         0   unknown
# 10827   no   cellular  ...       228        1     92         5   failure
# 10828   no   cellular  ...       127        2    196         1   success
# 10829   no   cellular  ...      1381        4     -1         0   unknown
# 10830   no   cellular  ...       113        4     -1         0   unknown
# 10831   no    unknown  ...       129        6     -1         0   unknown
# 10832   no   cellular  ...        69        1     -1         0   unknown
# 10833   no   cellular  ...       214        1     -1         0   unknown
# 10834   no   cellular  ...       160        1    119         2     other
# 10835   no   cellular  ...        76        6     -1         0   unknown
# 10836   no   cellular  ...       240        1    179         2   failure
# 10837   no   cellular  ...       131        2     -1         0   unknown
# 10838   no   cellular  ...       520        7     -1         0   unknown
# 10839   no   cellular  ...       130        3    188         2     other
# 10840   no   cellular  ...       400        1     -1         0   unknown
# 10841  yes   cellular  ...       181        1     -1         0   unknown
# 10842  yes   cellular  ...        17        7     -1         0   unknown
# 10843   no    unknown  ...        54        4     -1         0   unknown
# 10844  yes    unknown  ...       199        1     -1         0   unknown
# 10845  yes  telephone  ...        54        7     -1         0   unknown
# 10846   no   cellular  ...       258        2     -1         0   unknown
# 10847  yes    unknown  ...       257        3     -1         0   unknown
# 10848   no   cellular  ...        87        2     -1         0   unknown
# 10849   no    unknown  ...       193        2     -1         0   unknown
# 10850  yes   cellular  ...       135        3    363         2   failure
# 10851   no   cellular  ...       423        5     -1         0   unknown
#
#        job_age_count2 job_age_sum2  job_age_max2  job_age_min2  job_age_mean2
# 0                 316        14818            83            23      46.892405
# 1                2299        93373            81            21      40.614615
# 2                 555        34032            94            33      61.318919
# 3                 249         6562            41            18      26.353414
# 4                 316        14818            83            23      46.892405
# 5                1842        72539            70            21      39.380565
# 6                 966        37618            60            20      38.942029
# 7                 249         6562            41            18      26.353414
# 8                2299        93373            81            21      40.614615
# 9                1215        48141            69            20      39.622222
# 10               2299        93373            81            21      40.614615
# 11               1842        72539            70            21      39.380565
# 12               2307        92658            75            21      40.163849
# 13               2307        92658            75            21      40.163849
# 14                966        37618            60            20      38.942029
# 15               1842        72539            70            21      39.380565
# 16               2299        93373            81            21      40.614615
# 17                966        37618            60            20      38.942029
# 18               2307        92658            75            21      40.163849
# 19               2299        93373            81            21      40.614615
# 20               2307        92658            75            21      40.163849
# 21               1842        72539            70            21      39.380565
# 22               1842        72539            70            21      39.380565
# 23               2299        93373            81            21      40.614615
# 24               2307        92658            75            21      40.163849
# 25                966        37618            60            20      38.942029
# 26                966        37618            60            20      38.942029
# 27               2307        92658            75            21      40.163849
# 28                966        37618            60            20      38.942029
# 29               2307        92658            75            21      40.163849
# ...               ...          ...           ...           ...            ...
# 10822            1215        48141            69            20      39.622222
# 10823            1842        72539            70            21      39.380565
# 10824            1842        72539            70            21      39.380565
# 10825            1842        72539            70            21      39.380565
# 10826            2307        92658            75            21      40.163849
# 10827            1215        48141            69            20      39.622222
# 10828             555        34032            94            33      61.318919
# 10829            1842        72539            70            21      39.380565
# 10830            2299        93373            81            21      40.614615
# 10831            2307        92658            75            21      40.163849
# 10832            2299        93373            81            21      40.614615
# 10833             323        13049            60            21      40.399381
# 10834            2299        93373            81            21      40.614615
# 10835            2307        92658            75            21      40.163849
# 10836            2299        93373            81            21      40.614615
# 10837            1842        72539            70            21      39.380565
# 10838            2307        92658            75            21      40.163849
# 10839            1842        72539            70            21      39.380565
# 10840             966        37618            60            20      38.942029
# 10841             966        37618            60            20      38.942029
# 10842            1215        48141            69            20      39.622222
# 10843            1842        72539            70            21      39.380565
# 10844            1215        48141            69            20      39.622222
# 10845            2307        92658            75            21      40.163849
# 10846            2299        93373            81            21      40.614615
# 10847            2299        93373            81            21      40.614615
# 10848            2299        93373            81            21      40.614615
# 10849             966        37618            60            20      38.942029
# 10850            1215        48141            69            20      39.622222
# 10851            2307        92658            75            21      40.163849
#
# [10852 rows x 22 columns]

# %% [markdown]
# ## 众数特征

# %%
import scipy.stats as stats

# %%
data['job_age_mode'] = data.groupby(['job'])['age'].transform(lambda x: stats.mode(x)[0][0])

# %%
data.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  25318   51   housemaid  married    unknown      no      174      no   no
# 1  25319   32  management  married   tertiary      no     6059     yes   no
# 2  25320   60     retired  married    primary      no        0      no   no
# 3  25321   32     student   single   tertiary      no       64      no   no
# 4  25322   41   housemaid  married  secondary      no        0     yes  yes
#
#      contact  ...  campaign pdays  previous  poutcome  job_age_count2  \
# 0  telephone  ...         3    -1         0   unknown             316
# 1   cellular  ...         2    -1         0   unknown            2299
# 2  telephone  ...         3    -1         0   unknown             555
# 3   cellular  ...         4   105         5   failure             249
# 4   cellular  ...         4    -1         0   unknown             316
#
#    job_age_sum2 job_age_max2  job_age_min2  job_age_mean2  job_age_mode
# 0         14818           83            23      46.892405            54
# 1         93373           81            21      40.614615            34
# 2         34032           94            33      61.318919            59
# 3          6562           41            18      26.353414            27
# 4         14818           83            23      46.892405            54
#
# [5 rows x 23 columns]
